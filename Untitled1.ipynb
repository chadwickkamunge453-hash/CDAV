# %% [markdown]
# <a href="https://colab.research.google.com/github/chadwickkamunge453-hash/CDAV/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(20>10)
# Out:
# True

# %%
print(20<10)
# Out:
# False

# %%
print(5==5)
# Out:
# True

# %%
print(5!=5)
# Out:
# False

# %%
Name = input("what is your name? ")
Age = input("How old are you? ")
Course = input("What course are you doing? ")

print("===================")
print("STUDENT PROFILE")
print("===================")
print(Name)
print(Age)
print(Course)
# Out:
# what is your name? Chadwick
# How old are you? 19
# What course are you doing? CDAV
# ...
# STUDENT PROFILE
# ...
# Chadwick
# 19
# CDAV

# %%
Item_name = input("what item is it? ")
Price = float(input("What is the price? "))
Quantity = int(input("How many do you want? "))
print("Total = ",float(Price*Quantity))
# Out:
# what item is it? A pen
# What is the price? 1.50
# How many do you want? 3
# Total =  4.5

# %%
Weight = input("What is your weight in Kilograms? ")
Height = input("What is your height in Metres? ")
print("BMI = ",float(Weight)/(float(Height)*float(Height)))
# Out:
# What is your weight in Kilograms? 70
# What is your height in Metres? 1.6
# BMI =  27.343749999999996

# %%
user = input("Insert name: ")
print("Hello",user)
# Out:
# Insert name: Frank
# Hello Frank

# %%
length = input("What is the length of the room in metres? ")
width = input("What is the width of the room in metres? ")
print("the area of the room is",float(length)*float(width))
# Out:
# What is the length of the room in metres? 15.0
# What is the width of the room in metres? 1.1
# the area of the room is 16.5
