# %% [markdown]
# <a href="https://colab.research.google.com/github/chadwickkamunge453-hash/CDAV/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = [10,20,30]
numbers.insert(2,15)
print(numbers)
# Out:
# [10, 20, 15, 30]

# %%
numbers.remove(20)
print(numbers)
# Out:
# [10, 15, 30]

# %%
numbers.reverse()
print(numbers)
# Out:
# [10, 15, 30]

# %%
A = {1,2,3,3,4}
B = {3,4,5,6}
print(A)
print(B)
print("Union:",A|B)
print("Intersection:",A&B)
print("Difference:",A-B)
A.add(7)
A.remove(2)
print(A)
# Out:
# {1, 2, 3, 4}
# {3, 4, 5, 6}
# Union: {1, 2, 3, 4, 5, 6}
# Intersection: {3, 4}
# Difference; {1, 2}
# {1, 3, 4, 7}
