# %% [markdown]
# <a href="https://colab.research.google.com/github/chadwickkamunge453-hash/CDAV/blob/main/Loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# While loop

# %%
counter=1 #this counter hold the number of iterations
while counter<=5:
  print("Hello World")
  counter=counter+1
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World

# %%
x="***"
counter=0
while counter<3:
  print(x)
  counter=counter+1
  x=x+x
# Out:
# ***
# ******
# ************

# %%
is_correct=True
password="Secret"
count=3
while is_correct and count>0:
  user_pass = input("What is your password? ")
  if user_pass == password:
    print("Welcome back!")
    is_correct=False #control
  else:
    print("Incorrect password! Try again.")
    count=count-1
if count==0:
  print("Account locked")

# %%
number=7
x=("xx")
space1=(" ")
space=(" ")
count=0
while count<7:
  print((space1)+(x)+(x*number))
  space1=space1+space
  count=count+1 #control
  number=number-1
# Out:
#  xxxxxxxxxxxxxxxx
#   xxxxxxxxxxxxxx
#    xxxxxxxxxxxx
#     xxxxxxxxxx
#      xxxxxxxx
#       xxxxxx
#        xxxx

# %%
not_entered_zero = True
total=0
no_of_items=0
while not_entered_zero:
  val = float(input("Enter a value "))
  if val == 0:
    not_entered_zero = False
    print(total/no_of_items)
  else:
    total=tatal+val
    no_of_items=no_of_items+1
# Out:
# Enter a value 5
# Enter a value 5
# Enter a value 0
# 5.0
