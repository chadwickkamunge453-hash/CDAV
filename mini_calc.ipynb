# %% [markdown]
# <a href="https://colab.research.google.com/github/chadwickkamunge453-hash/CDAV/blob/main/mini_calc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
body_temperature= float(input("what is your body temperature? "))
print("Your body temperature is",body_temperature*1.8+32,"degrees farenheit")
# Out:
# what is your body temperature? 36
# Your body temperature is 96.8 degrees farenheit

# %%
print("Type any two numbers ")
x = float(input("x= "))
y = (float(input("y= ")))
print("sum is",x+y)
print("difference is",x-y)
print("multiplication is",x*y)
print("division is",x/y)
print("floor division is",x//y)
print("remainder is",x%y)
print("x to the power y is",x**y)
# Out:
# Type any two numbers
# x= 10
# y= 5
# sum is 15.0
# difference is 5.0
# multiplication is 50.0
# division is 2.0
# floor division is 2.0
# remainder is 0.0
# x to the power y is 100000.0
