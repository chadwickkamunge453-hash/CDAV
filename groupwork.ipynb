# %% [markdown]
# <a href="https://colab.research.google.com/github/chadwickkamunge453-hash/CDAV/blob/main/groupwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
students = []
more = "yes"

while more == "yes":
    name = input("Enter student name: ")
    age = input("Enter student age: ")
    gender = input("Enter student gender: ")

    student = {
        "name": name,
        "age": age,
        "gender": gender
    }

    students.append(student)

    more = input("Add another student? (yes/no): ")

index = 0
while index < len(students):
    print("Student", index + 1)
    print("Name:", students[index]["name"])
    print("Age:", students[index]["age"])
    print("Gender:", students[index]["gender"])
    print("\n")
    index = index + 1
# Out:
# Enter student name: John
# Enter student age: 17
# Enter student gender: M
# Add another student? (yes/no): no
# Student 1
# Name: John
# Age: 17
# Gender: M

# %%
students = []
more = "yes"
total = 0
while more == "yes":
    name = input("Enter student name: ")
    age = input("Enter student age: ")
    gender = input("Enter student gender: ")

    student = {
        "name": name,
        "age": age,
        "gender": gender
    }

    students.append(student)

    more = input("Add another student? (yes/no): ")

index = 0
while index < len(students):
    print("Student", index + 1)
    print("Name:", students[index]["name"])
    print("Age:", students[index]["age"])
    print("Gender:", students[index]["gender"])
    print("\n")
    index = index + 1
    total = total + 1

index=0
more_marks="yes"
marks=[]
while more_marks=="yes":
  print("Student",index +1,"marks")
  mark=int(input("Enter marks: "))
  mark={

  }
  marks.append(mark)
  index=index+1
  if total == index:
    break
# Out:
# Enter student name: bob
# Enter student age: 7
# Enter student gender: male
# Add another student? (yes/no): yes
# Enter student name: ann
# Enter student age: 6
# Enter student gender: female
# Add another student? (yes/no): yes
# Enter student name: abbie
# Enter student age: 7
# Enter student gender: female
# Add another student? (yes/no): no
# Student 1
# Name: bob
# Age: 7
# Gender: male
#
#
# Student 2
# Name: ann
# Age: 6
# Gender: female
#
#
# Student 3
# Name: abbie
# Age: 7
# Gender: female
#
#
# Student 1 marks
# Enter marks: 35
# Student 2 marks
# Enter marks: 91
# Student 3 marks
# Enter marks: 87
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_857/4019097877.py in <cell line: 0>()
#      40   if total == index:
#      41     break
# ---> 42 if mark <= 50:
#      43   print("Fail")
#      44 else:
#
# TypeError: '<=' not supported between instances of 'dict' and 'int'

# %%
failing_score=50
wh
marks = input("Enter your marks ")
marks=int(marks)
if marks<=50:
  print("")
# Out:
# Enter your marks 49
# failed
